# %%
path = r'''C:\Users\Dell\Downloads/bmw.jpg'''
file = open(path,mode='rb')
data = file.read()
from IPython import display
display.Image("bmw.jpg")
print('done')
# Out:
# done

# %%
type(data)
# Out:
# bytes

# %%
print(data)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00\x00\x00\x00\x00\x00\xff\xe1\x00BExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x01\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x02@\x00\x00\x03\x00\x00\x00\x01\x00\x8b\x00\x00@\x01\x00\x01\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\xdb\x00C\x00\x0b\t\t\x07\t\t\x07\t\t\t\t\x0b\t\t\t\t\t\t\x0b\t\x0b\x0b\x0c\x0b\x0b\x0b\x0c\r\x10\x0c\x11\x0e\r\x0e\x0c\x12\x19\x12%\x1a\x1d%\x1d\x19\x1f\x1c))\x16%756\x1a*2>-)0\x19;!\x13\xff\xdb\x00C\x01\x07\x08\x08\x0b\t\x0b\x15\x0b\x0b\x15,\x1d\x19\x1d,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,\xff\xc0\x00\x11\x08\x01\n\x01\xda\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\
# ...

# %%
f = open("bmw.jpg",mode='wb')
f.write(data)
print('done')

# %%
url = '''https://tse2.mm.bing.net/th/id/OIP.kxS_Nsy8cdNuds6W4pOMrQHaEK?rs=1&pid=ImgDetMain&o=7&rm=3'''
import requests as r
image_data = r.get(url).content
type(image_data)
from IPython import display
display.Image('bmw.jpg')

# %%
url = '''https://picsum.photos/200/300'''
import requests as r
for i in range(10):
   idata= r.get(url).content
   f=open(f'image_{i}.jpg','wb')
   f.write(idata)
   f.close()
   from IPython import display as d
    
   display(d.Image(f'image_{i},jpg',width = 200,height = 300))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\display.py:1128, in Image._data_and_metadata(self, always_both)
#    1127 try:
# -> 1128     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1129 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# ...

# %%
 url_path = '''https://www.python.org/ftp/python/3.13.5/python-3.13.5-amd64.exe'''
 import requests as r
with open(r'C:\Program Files','wb') as file:
    file.write(r.get(url_path.content))
print("done")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 url_path = '''https://www.python.org/ftp/python/3.13.5/python-3.13.5-amd64.exe'''
#       2 import requests as r
# ----> 3 with open(r'C:\Program Files','wb') as file:
#       4    file.write(r.get(url_path.content))
#       5 print("done")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Program Files'
